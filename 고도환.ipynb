# %% [markdown]
# <a href="https://colab.research.google.com/github/jx-dohwan/DATATHON/blob/main/%EA%B3%A0%EB%8F%84%ED%99%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/drive/MyDrive/인공지능/데이터톤/data/서울.csv')

# %%
data.head()
# Out:
#      상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명  \
# 0  23324279       제중건강원  NaN         D       소매       D10    건강/미용식품
# 1  24525909       민속악기사  NaN         D       소매       D04  취미/오락관련소매
# 2  24715368       태평양진주  NaN         D       소매       D26   시계/귀금속소매
# 3  15554136  김선희꼼꼼국어교습소  NaN         R    학문/교육       R01  학원-보습교습입시
# 4  17174175         비지트  NaN         Q       음식       Q01         한식
#
#   상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...                     건물관리번호     건물명  \
# 0    D10A07        건강원   G47216  ...  1156010600100410002034626     NaN
# 1    D04A09       악기판매   G47593  ...  1120012200101420011000227     NaN
# 2    D26A01     시계/귀금속   G47830  ...  1111015200100440000000001  금사랑투빌딩
# 3    R01A01      학원-입시   P85501  ...  1171011100101970003017195     NaN
# 4    Q01A01  한식/백반/한정식   I56111  ...  1165010100108540018009586   상랑의빌딩
#
#                      도로명주소   구우편번호   신우편번호  동정보  층정보  호정보          경도  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330827 entries, 0 to 330826
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     330827 non-null  int64
#  1   상호명        330827 non-null  object
#  2   지점명        58133 non-null   object
#  3   상권업종대분류코드  330827 non-null  object
#  4   상권업종대분류명   330827 non-null  object
#  5   상권업종중분류코드  330827 non-null  object
#  6   상권업종중분류명   330827 non-null  object
#  7   상권업종소분류코드  330827 non-null  object
#  8   상권업종소분류명   330827 non-null  object
#  9   표준산업분류코드   310386 non-null  object
#  10  표준산업분류명    310386 non-null  object
#  11  시도코드       330827 non-null  int64
#  12  시도명        330827 non-null  object
#  13  시군구코드      330827 non-null  int64
#  14  시군구명       330827 non-null  object
#  15  행정동코드      330827 non-null  int64
#  16  행정동명       330822 non-null  object
#  17  법정동코드      330827 non-null  int64
#  18  법정동명       330827 non-null  object
# ...

# %%
data['상권업종대분류명'].head()
# Out:
# 0       소매
# 1       소매
# 2       소매
# 3    학문/교육
# 4       음식
# Name: 상권업종대분류명, dtype: object

# %%
category = data['상권업종대분류명'].value_counts()

for i in category.keys():
  print(i)
# Out:
# 음식
# 소매
# 생활서비스
# 학문/교육
# 부동산
# 관광/여가/오락
# 스포츠
# 숙박

# %%
 food = data.loc[ data['상권업종대분류명']=='음식']

# %%
food['상권업종소분류명'].unique()
# Out:
# array(['한식/백반/한정식', '민속주점', '족발/보쌈전문', '곱창/양구이전문', '커피전문점/카페/다방', '토스트전문',
#        '삼계탕전문', '중국음식/중국집', '패밀리레스토랑', '제과점', '떡전문', '부대찌개/섞어찌개',
#        '국수/만두/칼국수', '닭내장/닭발요리', '죽전문점', '호프/맥주', '빠/카페/스탠드빠', '도시락전문점',
#        '해장국/감자탕', '두부요리전문', '파전전문', '라면김밥분식', '후라이드/양념치킨', '구내식당/자급식음식점',
#        '패스트푸드', '소주방/포장마차', '갈비/삼겹살', '정통양식/경양식', '돌솥/비빕밥전문점', '복전문',
#        '도너츠전문', '로바다야끼', '룸살롱/단란주점', '횟집', '음식점-일식', '스파게티전문점', '기사식당',
#        '갈치/생선구이', '아구전문', '떡볶이전문', '냉면집', '아이스크림판매', '종합부페', '찜닭전문점',
#        '꼬치구이전문점', '순대전문점', '보드게임카페', '기타일반유흥주점', '해물찜/탕전문', '닭갈비전문',
#        '추어탕전문', '순두부전문', '스낵', '곰장어전문', '기타전문서양음식점', '떡/한과집', '피자전문',
#        '참치전문점', '우동전문점', '설렁탕집', '전통찻집/인삼찻집', '홍어전문', '야식집', '오리고기전문',
#        '한정식전문', '음식점-초밥전문', '샌드위치전문점', '민물장어전문', '바베큐전문', '돈가스전문점', '핫도그',
#        '낙지/오징어', '샤브샤브전문', '기타고기요리', '매운탕전문', '수산물전문음식점-종합', '음식출장조달',
#        '생과일주스전문점', '퓨전음식전문', '게장전문', '동남아음식전문점', '사철탕전문', '철판구이요리전문',
# ...

# %%
food['상권업종소분류명'].value_counts().iloc[0:30]
# Out:
# 한식/백반/한정식      26412
# 커피전문점/카페/다방    18866
# 호프/맥주           5800
# 라면김밥분식          5491
# 후라이드/양념치킨       4143
# 갈비/삼겹살          3853
# 제과점             3707
# 정통양식/경양식        3558
# 중국음식/중국집        3301
# 음식점-일식          3055
# 국수/만두/칼국수       2164
# 피자전문            1559
# 떡볶이전문           1496
# 패스트푸드           1433
# 족발/보쌈전문         1299
# 아이스크림판매         1262
# 곱창/양구이전문        1252
# 소주방/포장마차        1211
# 룸살롱/단란주점        1129
# 음식점-초밥전문        1079
# 빠/카페/스탠드빠       1071
# 해장국/감자탕         1036
# 기타일반유흥주점         996
# 순대전문점            963
# 기타전문서양음식점        944
# 횟집               886
# 돈가스전문점           832
# 떡전문              702
# 기타고기요리           691
# 동남아음식전문점         609
# Name: 상권업종소분류명, dtype: int64

# %%
category = data['상권업종대분류명'].value_counts()

category.keys()
for i in category.keys():
    print(i)
# Out:
# 음식
# 소매
# 생활서비스
# 학문/교육
# 부동산
# 관광/여가/오락
# 스포츠
# 숙박

# %%
category = data['상권업종대분류명'].value_counts()

store = {}
for i in category.keys():
    store[i] = data.loc[data['상권업종대분류명']==i]
store['음식'].head()
# Out:
#      상가업소번호     상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 4  17174175     비지트  NaN         Q       음식       Q01       한식    Q01A01
# 5  17174119    쓰리에프  NaN         Q       음식       Q01       한식    Q01A01
# 6  17174096      채움  NaN         Q       음식       Q01       한식    Q01A01
# 7  17174040      다향  NaN         Q       음식       Q01       한식    Q01A01
# 8  25530299  고향생막걸리  NaN         Q       음식       Q09     유흥주점    Q09A04
#
#     상권업종소분류명 표준산업분류코드  ...                     건물관리번호       건물명  \
# 4  한식/백반/한정식   I56111  ...  1165010100108540018009586     상랑의빌딩
# 5  한식/백반/한정식   I56111  ...  1159010700101390073009536       NaN
# 6  한식/백반/한정식   I56111  ...  1111012400100580000017956  두산위브파빌리온
# 7  한식/백반/한정식   I56111  ...  1165010800114850004022127       NaN
# 8       민속주점   I56219  ...  1168010700106150001009703     코끼리상가
#
#                    도로명주소   구우편번호   신우편번호  동정보  층정보  호정보          경도         위도
# ...

# %%
Franchise = store['음식']['상호명'].value_counts()

Franchise[1:21]
# Out:
# 이디야커피       385
# 스타벅스        326
# BBQ치킨       205
# 파리바게뜨       201
# 메가엠지씨커피     176
# 투썸플레이스      172
# BHC치킨       169
# 컴포즈커피       164
# 나           162
# 김밥천국        149
# 커피빈         136
# 빽다방         124
# 뚜레쥬르        118
# 배스킨라빈스31    110
# 김가네         107
# 공차          105
# 까           104
# 본죽          103
# 교촌치킨         98
# 이삭토스트        96
# Name: 상호명, dtype: int64

# %%
franchise = Franchise[1:21].keys()

print(franchise)
# Out:
# Index(['이디야커피', '스타벅스', 'BBQ치킨', '파리바게뜨', '메가엠지씨커피', '투썸플레이스', 'BHC치킨',
#        '컴포즈커피', '나', '김밥천국', '커피빈', '빽다방', '뚜레쥬르', '배스킨라빈스31', '김가네', '공차',
#        '까', '본죽', '교촌치킨', '이삭토스트'],
#       dtype='object')

# %% [markdown]
# ### 음식점별 위도 경도 위치를 뽑아내기

# %%
이디야 = store['음식'].loc[store['음식']['상호명']=='이디야커피']

# %%
이디야_위경도 = 이디야[['위도', '경도']]

# %%
이디야_위경도
# Out:
#                위도          경도
# 1107    37.515118  126.918062
# 1463    37.519544  126.939198
# 2426    37.449066  126.913646
# 4244    37.486436  126.854872
# 5404    37.504253  126.922245
# ...           ...         ...
# 311278  37.478714  126.999766
# 311554  37.636868  127.026984
# 316487  37.554739  126.964594
# 321643  37.480126  127.126630
# 324132  37.471343  126.903273
#
# [385 rows x 2 columns]

# %%
m = folium.Map(location=[37.515118,126.918062],zoom_start=14)

# %%
folium.Marker([37.515118,126.918062]).add_to(m)

# %%
for 위도, 경도 in zip(이디야['위도'],이디야['경도']):
  folium.Marker([위도,경도]).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
교촌치킨 = store['음식'].loc[store['음식']['상호명']=='교촌치킨']
교촌치킨_위경도 = 교촌치킨[['위도', '경도']]
교촌치킨_위경도
# Out:
#                위도          경도
# 1494    37.538361  126.840828
# 5375    37.530414  126.970044
# 5864    37.495380  126.985634
# 8029    37.551890  127.033511
# 9709    37.617533  127.063846
# ...           ...         ...
# 284953  37.630000  127.056654
# 286554  37.623096  127.073485
# 299412  37.663153  127.066186
# 299486  37.500489  126.949555
# 328283  37.541859  127.095731
#
# [98 rows x 2 columns]

# %%
m2 = folium.Map(location=[37.515118,126.918062],zoom_start=14)

# %%
for 위도, 경도 in zip(이디야['위도'],이디야['경도']):
  folium.Marker([위도,경도]).add_to(m2)
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
