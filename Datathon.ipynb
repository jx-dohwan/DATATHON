# %%
import os, sys

from os.path import join
import pandas as pd

data_dir = 'C:/Users/strfg/OneDrive/바탕 화면/AIFFEL-exploration/소상공인시장진흥공단_상가(상권)정보_20220331/소상공인시장진흥공단_상가(상권)정보_대전_202203.csv'
data = pd.read_csv(data_dir)

# %%
data.head()
# Out:
#      상가업소번호         상호명    지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명  \
# 0  22401931      스피드메이트    NaN         F    생활서비스       F14    자동차/이륜차
# 1  24185362  국제종합기계부품총판    NaN         D       소매       D25      기타판매업
# 2  22742209    알파수학전문학원    NaN         R    학문/교육       R01  학원-보습교습입시
# 3  17174039         솔바람    NaN         Q       음식       Q01         한식
# 4  17174056       BBQ치킨  대전대흥점         Q       음식       Q09       유흥주점
#
#   상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...                     건물관리번호   건물명  \
# 0    F14A01  자동차정비/카센타      NaN  ...  3020014600111220000001772   NaN
# 1    D25A15      농기구판매   G47512  ...  3017010300101730001030969  써머스빌
# 2    R01A01      학원-입시   P85501  ...  3014010200101570008028501  선우빌딩
# 3    Q01A01  한식/백반/한정식   I56111  ...  3020012000109080016009529   NaN
# 4    Q09A01      호프/맥주   I56219  ...  3014010500101180005012316   NaN
#
#                      도로명주소   구우편번호    신우편번호  동정보  층정보  호정보          경도  \
# 0        대전광역시 유성구 관들4길 25  305509  34018.0  NaN  NaN  NaN  127.393241
# 1        대전광역시 서구 계백로 1426  302160  35400.0  NaN  NaN  NaN  127.379765
# 2      대전광역시 중구 선화서로 128-1  301824  34841.0  NaN    2  NaN  127.413968
# 3  대전광역시 유성구 은구비서로3번길 8-23  305330  34086.0  NaN  NaN  NaN  127.320105
# 4         대전광역시 중구 대흥로 158  301802  34928.0  NaN    1  NaN  127.429579
#
#           위도
# 0  36.424448
# 1  36.312625
# 2  36.334319
# 3  36.373504
# 4  36.324517
#
# [5 rows x 39 columns]

# %%
category = data['상권업종대분류명'].value_counts()

category.keys()
for i in category.keys():
    print(i)
# Out:
# 소매
# 음식
# 생활서비스
# 학문/교육
# 부동산
# 관광/여가/오락
# 스포츠
# 숙박

# %%
category = data['상권업종대분류명'].value_counts()

store = {}
for i in category.keys():
    store[i] = data.loc[data['상권업종대분류명']==i]
store['음식'].head()
# Out:
#      상가업소번호     상호명    지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 3  17174039     솔바람    NaN         Q       음식       Q01       한식    Q01A01
# 4  17174056   BBQ치킨  대전대흥점         Q       음식       Q09     유흥주점    Q09A01
# 5  17173834      장군    NaN         Q       음식       Q01       한식    Q01A02
# 6  25382269   커피기념일    NaN         Q       음식       Q12   커피점/카페    Q12A01
# 7  20287192  도마인더키친    NaN         Q       음식       Q01       한식    Q01A01
#
#       상권업종소분류명 표준산업분류코드  ...                     건물관리번호   건물명  \
# 3    한식/백반/한정식   I56111  ...  3020012000109080016009529   NaN
# 4        호프/맥주   I56219  ...  3014010500101180005012316   NaN
# 5       갈비/삼겹살   I56111  ...  3017010800104260011007377   NaN
# 6  커피전문점/카페/다방   I56220  ...  3014010500104210001008227  정문빌라
# 7    한식/백반/한정식   I56111  ...  3020013900106590002000001   NaN
#
#                      도로명주소   구우편번호    신우편번호  동정보  층정보  호정보          경도  \
# 3  대전광역시 유성구 은구비서로3번길 8-23  305330  34086.0  NaN  NaN  NaN  127.320105
# 4         대전광역시 중구 대흥로 158  301802  34928.0  NaN    1  NaN  127.429579
# 5     대전광역시 서구 도산로369번길 51  302816  35299.0  NaN  NaN  NaN  127.390027
# 6     대전광역시 중구 보문로230번길 62  301803  34919.0  NaN    1  NaN  127.426196
# 7  대전광역시 유성구 반석로11번길 66-17  305150  34068.0  NaN    1  NaN  127.315486
#
#           위도
# 3  36.373504
# 4  36.324517
# 5  36.339021
# 6  36.324122
# 7  36.389276
#
# [5 rows x 39 columns]

# %%
category_상호명=store['음식']['상호명'].unique()

Franchise = store['음식']['상호명'].value_counts()

Franchise[:20]
# Out:
# 카페          157
# 파리바게뜨        46
# 빽다방          41
# 스타벅스         40
# BBQ치킨        39
# BHC치킨        35
# 디에떼에스프레소     35
# 이디야커피        34
# 투썸플레이스       34
# 김밥천국         32
# 페리카나         32
# 처갓집양념치킨      29
# 본죽           28
# 또봉이통닭        28
# 투다리          28
# 롯데리아         28
# 나            28
# 김가네          25
# 피자마루         24
# 역전할머니맥주      24
# Name: 상호명, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\strfg\OneDrive\바탕 화면\AIFFEL-exploration\Datathon.ipynb 셀 6 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/strfg/OneDrive/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/AIFFEL-exploration/Datathon.ipynb#ch0000003?line=0'>1</a> store_csv_path = '{}/대전.csv'.format(data_dir)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/strfg/OneDrive/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/AIFFEL-exploration/Datathon.ipynb#ch0000003?line=1'>2</a> store.to_csv(store_csv_path, index=False)
#
# File c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
#    3555     encoding=encoding,
#    3556     errors=errors,
#    3557     compression=compression,
#    3558     quoting=quoting,
#    3559     columns=columns,
#    3560     index_label=index_label,
#    3561     mode=mode,
#    3562     chunksize=chunksize,
#    3563     quotechar=quotechar,
#    3564     date_format=date_format,
#    3565     doublequote=doublequote,
#    3566     escapechar=escapechar,
#    3567     storage_options=storage_options,
#    3568 )
#
# File c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:1180, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1159     created_buffer = False
#    1161 csv_formatter = CSVFormatter(
#    1162     path_or_buf=path_or_buf,
#    1163     line_terminator=line_terminator,
#    (...)
#    1178     formatter=self.fmt,
#    1179 )
# -> 1180 csv_formatter.save()
#    1182 if created_buffer:
#    1183     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.line_terminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py:694, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     692 # Only for write methods
#     693 if "r" not in mode and is_path:
# --> 694     check_parent_directory(str(handle))
#     696 if compression:
#     697     if compression != "zstd":
#     698         # compression libraries do not like an explicit text-mode
#
# File c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py:568, in check_parent_directory(path)
#     566 parent = Path(path).parent
#     567 if not parent.is_dir():
# --> 568     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'C:\Users\strfg\OneDrive\바탕 화면\AIFFEL-exploration\소상공인시장진흥공단_상가(상권)정보_20220331\소상공인시장진흥공단_상가(상권)정보_대전_202203.csv'
